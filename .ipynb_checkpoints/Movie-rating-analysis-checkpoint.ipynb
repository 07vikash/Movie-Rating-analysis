# %%
import pandas as pd
import os

# %%
movieData = pd.read_csv(r'Movie-rating.csv')

# %%
movieData
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movieData)
# Out:
# 559

# %%
movieData.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movieData.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movieData.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movieData.columns = ['Film','Genre','CritingRating','AudienceRating','BudgetMillions','Year']
movieData.head()
# Out:
#                     Film      Genre  CritingRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movieData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CritingRating   559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movieData.describe()
# Out:
#        CritingRating  AudienceRating  BudgetMillions         Year
# count     559.000000      559.000000      559.000000   559.000000
# mean       47.309481       58.744186       50.236136  2009.152057
# std        26.413091       16.826887       48.731817     1.362632
# min         0.000000        0.000000        0.000000  2007.000000
# 25%        25.000000       47.000000       20.000000  2008.000000
# 50%        46.000000       58.000000       35.000000  2009.000000
# 75%        70.000000       72.000000       65.000000  2010.000000
# max        97.000000       96.000000      300.000000  2011.000000

# %%
movieData['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movieData.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movieData.Film =movieData.Film.astype('category')

# %%
movieData.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movieData.head()
# Out:
#                     Film      Genre  CritingRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movieData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CritingRating   559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movieData.Genre = movieData.Genre.astype('category')
movieData.Year = movieData.Year.astype('category')

# %%
movieData.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movieData.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movieData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CritingRating   559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movieData.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movieData.describe()
# Out:
#        CritingRating  AudienceRating  BudgetMillions
# count     559.000000      559.000000      559.000000
# mean       47.309481       58.744186       50.236136
# std        26.413091       16.826887       48.731817
# min         0.000000        0.000000        0.000000
# 25%        25.000000       47.000000       20.000000
# 50%        46.000000       58.000000       35.000000
# 75%        70.000000       72.000000       65.000000
# max        97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * Basically joint plot is a scatter plot & it find the relation   b/w audience & critics.
# * Also if you look up you can find the uniform distribution       (critics) and normal distribution (audience)

# %%
vis1 = sns.jointplot(data = movieData, x = 'CritingRating', y = 'AudienceRating')

# %% [markdown]
# * Audience rating is more dominant then critics rating.
# * Based on this we find out as most people are most likehood to watch audience rating & less likely to wathc critics rating
# * let me explain the excel - if you filter audience rating & critic Rating. Critic rating has very low values compare to audience rating.

# %%
vis2 = sns.jointplot(data =movieData, x= 'CritingRating', y = 'AudienceRating', kind = 'reg')

# %%
vis3 = sns.jointplot(data =movieData, x='CritingRating', y='AudienceRating', kind='hex')

# %%
hist1 = sns.distplot(movieData.AudienceRating,)

# %% [markdown]
# * y-axis generated automatically by seaborn that's seaborn power

# %%
sns.set_style('darkgrid')

# %%
hist2 = sns.distplot(movieData.AudienceRating, bins= 15)

# %%
hist3 = plt.hist(movieData.AudienceRating, bins=15)

# %%
sns.set_style('white')
hist4 = plt.hist(movieData.AudienceRating, bins =20)

# %%
hist5 =plt.hist(movieData.CritingRating, bins =20)

# %%
plt.hist(movieData.BudgetMillions)
plt.show()

# %%
plt.hist(movieData[movieData.Genre == 'Drama']. BudgetMillions)
plt.show()

# %%
movieData.head()
# Out:
#                     Film      Genre  CritingRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
plt.hist(movieData[movieData.Genre == 'Action'].BudgetMillions, bins=20)
plt.hist(movieData[movieData.Genre == 'Thriller'].BudgetMillions, bins=20)
plt.hist(movieData[movieData.Genre =='Drama'].BudgetMillions, bins =20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movieData[movieData.Genre == 'Action'].BudgetMillions,\
         movieData[movieData.Genre == 'Drama'].BudgetMillions,\
         movieData[movieData.Genre =='Thriller'].BudgetMillions,\
         movieData[movieData.Genre == 'Comedy'].BudgetMillions],
        bins =20, stacked = True)
plt.show()

# %%
for gen in movieData.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis00 = sns.lmplot(data=movieData, x='CritingRating', y='AudienceRating',\
                 fit_reg=False)

# %%
vis01 = sns.lmplot(data=movieData, x='CritingRating', y='AudienceRating',\
                  fit_reg=False, hue = 'Genre')

# %%
#sns.set_style('dark')
vis02 = sns.lmplot(data=movieData, x='CritingRating', y='AudienceRating',\
                 fit_reg=False, hue = 'Genre', size = 10,aspect=1)

# %%
k1 = sns.kdeplot(movieData.CritingRating, movieData.AudienceRating)

# %%
sns.set_style('white')
k01 = sns.kdeplot(movieData.CritingRating, movieData.AudienceRating,shade=True,  shade_lowest=False, cmap='Reds')

# %%
k02 = sns.kdeplot(movieData.CritingRating, movieData.AudienceRating, shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
kk1 = sns.kdeplot(movieData.BudgetMillions, movieData.AudienceRating, shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
kk01 = sns.kdeplot(movieData.BudgetMillions, movieData.AudienceRating)

# %%
kk02 = sns.kdeplot(movieData.BudgetMillions, movieData.CritingRating)
